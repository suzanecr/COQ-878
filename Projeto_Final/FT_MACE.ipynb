# %% [markdown]
# # Install

# %%
pip install git+https://github.com/imagdau/aseMolec@f411b5618381ba3b807cbbb041f12f460a69d606
# Out:
# ...
#   Cloning https://github.com/imagdau/aseMolec (to revision f411b5618381ba3b807cbbb041f12f460a69d606) to /tmp/pip-req-build-eo4hropo
#   Running command git clone --filter=blob:none --quiet https://github.com/imagdau/aseMolec /tmp/pip-req-build-eo4hropo
#   Running command git rev-parse -q --verify 'sha^f411b5618381ba3b807cbbb041f12f460a69d606'
#   Running command git fetch -q https://github.com/imagdau/aseMolec f411b5618381ba3b807cbbb041f12f460a69d606
#   Resolved https://github.com/imagdau/aseMolec to commit f411b5618381ba3b807cbbb041f12f460a69d606
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for aseMolec: filename=aseMolec-1.0.0-py3-none-any.whl size=23162 sha256=ab0db985341b4f5f59ffef3bd3629397650e047116392e9ce960ec5d72e581c4
#   Stored in directory: /root/.cache/pip/wheels/bf/ab/ed/45f9be5430256a5678b55aeccaeb233ab05ac03514a7805562
# Successfully built aseMolec
# ...

# %%
pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...

# %%
pip install mace-torch cuequivariance cuequivariance-torch cuequivariance-ops-torch-cu12 torch-dftd
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.1/237.1 kB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.7/387.7 kB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.7/266.7 kB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.8/216.8 kB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.3/406.3 kB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 72.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.7/681.7 kB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 117.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 104.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 35.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import

# %%
import os
from ase.io import write, read
from ase import units
from ase.md.langevin import Langevin
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution, Stationary, ZeroRotation

import time
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Função Auxiliar para DM no ASE

# %%
np.random.seed(701) # fixa uma seed aleatória

def simpleMD(init_conf, temp, calc, fname, s, T):
    init_conf.calc = calc

    MaxwellBoltzmannDistribution(init_conf, temperature_K=300)
    Stationary(init_conf)
    ZeroRotation(init_conf)

    dyn = Langevin(init_conf, 0.5*units.fs, temperature_K=temp, friction=0.1)

    time_fs = []
    temperature = []
    energies = []

    os.system('rm -rfv '+fname) #limpa o arquivo de dados prévios com mesmo nome

    fig, ax = plt.subplots(2, 1, figsize=(6,6), sharex='all', gridspec_kw={'hspace': 0, 'wspace': 0})

    def write_frame():
            dyn.atoms.info['energy_mace'] = dyn.atoms.get_potential_energy()
            dyn.atoms.arrays['forces_mace'] = dyn.atoms.calc.get_forces()
            dyn.atoms.write(fname, append=True)
            time_fs.append(dyn.get_time()/units.fs)
            temperature.append(dyn.atoms.get_temperature())
            energies.append(dyn.atoms.get_potential_energy()/len(dyn.atoms))

            ax[0].plot(np.array(time_fs), np.array(energies), color="b")
            ax[0].set_ylabel('E (eV/atom)')

            ax[1].plot(np.array(time_fs), temperature, color="r")
            ax[1].set_ylabel('T (K)')
            ax[1].set_xlabel('Time (fs)')

            display.clear_output(wait=True)
            display.display(plt.gcf())
            time.sleep(0.01)

    dyn.attach(write_frame, interval=s)
    t0 = time.time()
    dyn.run(T)
    t1 = time.time()
    print("MD finished in {0:.2f} minutes!".format((t1-t0)/60))

# %% [markdown]
# # FINE TUNNING

# %%
traj = read('/content/drive/MyDrive/COQ878_TRABALHO/MACE/HAP_EtOH_100passos.xyz', ':')
print(len(traj))
write('/content/drive/MyDrive/COQ878_TRABALHO/MACE/HAP_EtOH_100passos_train.xyz', traj[:13])
write('/content/drive/MyDrive/COQ878_TRABALHO/MACE/HAP_EtOH_100passos_test.xyz', traj[8:])
# Out:
# 21

# %%
# !mace_run_train \
    --name="finetuned_MACE" \
    --foundation_model="small" \
    --multiheads_finetuning=False \
    --stress_weight=0.0 \
    --forces_weight=1.0 \
    --energy_weight=1.0 \
    --model_dir="/content/drive/MyDrive/COQ878_TRABALHO/MACE" \
    --log_dir="/content/drive/MyDrive/COQ878_TRABALHO/MACE" \
    --checkpoints_dir="/content/drive/MyDrive/COQ878_TRABALHO/MACE" \
    --train_file="/content/drive/MyDrive/COQ878_TRABALHO/MACE/HAP_EtOH_100passos_train.xyz" \
    --valid_fraction=0.9 \
    --test_file="/content/drive/MyDrive/COQ878_TRABALHO/MACE/HAP_EtOH_100passos_test.xyz" \
    --energy_key="energy_vasp" \
    --forces_key="forces_vasp" \
    --E0s="average" \
    --lr=0.01 \
    --scaling="rms_forces_scaling" \
    --batch_size=2 \
    --max_num_epochs=6 \
    --ema \
    --ema_decay=0.99 \
    --amsgrad \
    --default_dtype="float64" \
    --device=cuda \
    --seed=3
# Out:
# /usr/local/lib/python3.12/dist-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# 2025-12-10 21:01:49.782 INFO: ===========VERIFYING SETTINGS===========
# 2025-12-10 21:01:49.785 INFO: MACE version: 0.3.14
# 2025-12-10 21:01:49.852 INFO: CUDA version: 12.6, CUDA device: 0
# 2025-12-10 21:01:50.057 INFO: Using foundation model mace-mp-0 small as initial checkpoint.
# ...
# Cached MACE model to /root/.cache/mace/20231210mace128L0_energy_epoch249model
# Using Materials Project MACE for MACECalculator with /root/.cache/mace/20231210mace128L0_energy_epoch249model
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# ...

# %% [markdown]
# # Rodar MACE pós treinamento

# %%
from mace.calculators import MACECalculator

macenew = MACECalculator(model_path="/content/drive/MyDrive/COQ878_TRABALHO/MACE/finetuned_MACE.model", device="cuda",default_dtype = "float32")
# Out:
# /usr/local/lib/python3.12/dist-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# WARNING:root:'model_path' argument is deprecated, please use 'model_paths' in the future.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
init_conf = read('/content/drive/MyDrive/COQ878_TRABALHO/MACE/frame_900.pdb')

np.random.seed(701)

simpleMD(init_conf, temp=300, calc=macenew, fname='/content/drive/MyDrive/COQ878_TRABALHO/MACE/mymace_md.xyz', s=10, T=20000)
# Out:
# MD finished in 142.81 minutes!
