# %% [markdown]
# Salvar um frame específico em .pdb a partir de um arquivo de trajetórias em .xyz

# %%
pip install ase
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 32.4 MB/s eta 0:00:00
# ...

# %%
import os
from ase.io import write, read

import time
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
traj = read("/content/drive/MyDrive/COQ878_TRABALHO/HAP_EtOH.xyz", index=":")
frame_900 = traj[899]  # índice começa em 0 → frame 900 = índice 899

write("/content/drive/MyDrive/COQ878_TRABALHO/frame_900.pdb", frame_900)
